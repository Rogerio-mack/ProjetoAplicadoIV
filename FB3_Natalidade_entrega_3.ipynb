# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/ProjetoAplicadoIV/blob/main/FB3_Natalidade_entrega_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   <img src="https://github.com/Rogerio-mack/GCF/raw/main/GCF_files/Mackenzie.jpg" width="25%" align="right"/>
#
#   # **PROJETO APLICADO IV - Entrega 3**
#
#   <br>
#   <br>

# %% [markdown]
# # **Impacto da Baixa Taxa de Natalidade na Previdência Social: Um Desafio para o Futuro**
# ---

# %%
#@title **Identificação do Grupo e Opção do Projeto**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
Aluno1 = 'Douglas Pereira de Araújo, RA 10370116' #@param {type:"string"}
Aluno2 = 'Gabriel Sicari Moretti, RA 1036984' #@param {type:"string"}
Aluno3 = 'João Vitor da Silva Pereira, RA 10369433' #@param {type:"string"}
Aluno4 = 'Matheus Aparecido Ramos Lourenço, RA 10368895' #@param {type:"string"}
Aluno5 = 'Rafael Castro dos Santos, RA 10368801' #@param {type:"string"}

# %%
#@title **Avaliação**
EDA_e_preprocessamento = 8 #@param {type:"slider", min:0, max:10, step:1}

Modelo_base = 7 #@param {type:"slider", min:0, max:10, step:1}

Revisao = 6 #@param {type:"slider", min:0, max:10, step:1}

Apresentacao_geral = 6 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = 0.4*EDA_e_preprocessamento + 0.2*Modelo_base + 0.2*Revisao + 0.2*Apresentacao_geral

print(f'Nota final do trabalho {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_nome.append(lista[0]);")

alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota final do trabalho 7.0
#                                nome  nota
# 0         Douglas Pereira de Araújo   7.0
# 1            Gabriel Sicari Moretti   7.0
# 2       João Vitor da Silva Pereira   7.0
# 3  Matheus Aparecido Ramos Lourenço   7.0
# 4          Rafael Castro dos Santos   7.0

# %% [markdown]
# # Comentários
#
# Não esperava no modelo, nesta etapa, estar completamente documentado e analisado, mas da forma que está ainda está  longe de fornecer uma legibilidade do modelo. Espero que ajustem isso bastante bem para oa entrega final... uma lista de códigos, mesmo comentados, parece ser pouco suficiente.
#
# Não parece correto aplicar um modelo ARIMA quando, aparentemente temos uma série sazonal. Um SARIMA seria mais adequado neste caso. Não vi a análise, ou por que não está aqui de fato ou pela falta de organização dessa parte da implementação (sim, entendo que é uma 1a versão, sem problemas), de como chegam aos parâmetros do ARIMA... não teriam que fazer um PACF ACF ? Fica também a sugestão de empregarem o pmdarima (auto arima) para busca dos melhores parâmetros. Avaliei de qualquer modo bem o modelo base (7.0) pois acredito que tenham aqui potencial para criar modelo final bastante aceitável. Precisam, entretanto, organizar, explicar e justificar as escolhas de parâmetros etc. Além de que precisam incluir análises dos resultados que incluem, além do erro a análise de resíduos. Lembrem-se, ciência de dados trata de comunicar os resultados das análises e, neste ponto, ficam devendo para entrega final.
#
# Ah, cuidado com os warnings dos modelos. Muitos indicam que o modelo não converge! E revejam o que acontece com esse notebook. Não abre pelo link do Colab, tem figuras que não estão no notebook, gráficos que não aparecem... Aqui o erro e, por isso, somente salvei a avaliação
#
# Invalid Notebook
# missing attachment: image.png
# Using nbformat v5.10.4 and nbconvert v7.16.1
